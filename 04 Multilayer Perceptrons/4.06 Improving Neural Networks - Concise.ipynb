# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_moons

# %% [markdown]
# ### Data

# %%
features, labels = make_moons(n_samples=5000, random_state=42, noise=0.1)

# %%
features.shape, labels.shape
# Out:
# ((5000, 2), (5000,))

# %%
features[:5]
# Out:
# array([[-0.1196884 ,  1.03684845],
#        [ 0.03370055,  0.2493631 ],
#        [ 0.03864294,  0.33033539],
#        [ 0.22222051,  1.03355193],
#        [ 0.74448612,  0.69288687]])

# %%
labels[:5]
# Out:
# array([0, 1, 1, 0, 0], dtype=int64)

# %%
plt.scatter(features[:,0], features[:,1], c = labels, cmap = plt.cm.RdYlBu_r)

# %% [markdown]
# ### Training

# %%
model = tf.keras.models.Sequential()
lambd = 0.01
model.add(tf.keras.layers.Flatten(input_shape=(2, )))
model.add(tf.keras.layers.Dense(200, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(lambd)))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(200, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(lambd)))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(2, activation='softmax', kernel_regularizer=tf.keras.regularizers.l2(lambd)))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 2)                 0
# _________________________________________________________________
# dense (Dense)                (None, 200)               600
# _________________________________________________________________
# dropout (Dropout)            (None, 200)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 200)               40200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 402
# =================================================================
# Total params: 41,202
# Trainable params: 41,202
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_train, X_test, y_train, y_test = train_test_split(features, labels, random_state=42)

# %%
model.compile(loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
                optimizer = tf.keras.optimizers.Adam(lr = 0.01),
                metrics = ['accuracy'])

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10)
# Out:
# Epoch 1/10
# 118/118 [==============================] - 0s 3ms/step - loss: 0.5065 - accuracy: 0.8824 - val_loss: 0.3271 - val_accuracy: 0.9456
# Epoch 2/10
# 118/118 [==============================] - 0s 2ms/step - loss: 0.3396 - accuracy: 0.9499 - val_loss: 0.2966 - val_accuracy: 0.9664
# Epoch 3/10
# 118/118 [==============================] - 0s 2ms/step - loss: 0.3301 - accuracy: 0.9571 - val_loss: 0.3090 - val_accuracy: 0.9648
# Epoch 4/10
# 118/118 [==============================] - 0s 2ms/step - loss: 0.3173 - accuracy: 0.9643 - val_loss: 0.2893 - val_accuracy: 0.9776
# Epoch 5/10
# 118/118 [==============================] - 0s 2ms/step - loss: 0.3250 - accuracy: 0.9672 - val_loss: 0.3024 - val_accuracy: 0.9776
# Epoch 6/10
# 118/118 [==============================] - 0s 2ms/step - loss: 0.3200 - accuracy: 0.9656 - val_loss: 0.3312 - val_accuracy: 0.9656
# Epoch 7/10
# 118/118 [==============================] - 0s 2ms/step - loss: 0.3276 - accuracy: 0.9605 - val_loss: 0.2935 - val_accuracy: 0.9744
# Epoch 8/10
# 118/118 [==============================] - 0s 2ms/step - loss: 0.3200 - accuracy: 0.9648 - val_loss: 0.2888 - val_accuracy: 0.9792
# Epoch 9/10
# 118/118 [==============================] - 0s 2ms/step - loss: 0.3238 - accuracy: 0.9667 - val_loss: 0.3156 - val_accuracy: 0.9728
# Epoch 10/10
# 118/118 [==============================] - 0s 2ms/step - loss: 0.3173 - accuracy: 0.9712 - val_loss: 0.2924 - val_accuracy: 0.9720

# %% [markdown]
# ### Decision Boundary

# %%
def plot_decision_boundary(net, X, y):
    # Define the axis boundaries of the plot and create a meshgrid
    x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
    y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100),
                       np.linspace(y_min, y_max, 100))
    # Create X values (we're going to predict on all of these)
    x_in = np.c_[xx.ravel(), yy.ravel()] 
    # Make predictions using the trained model
    y_pred = np.array(model(x_in)).argmax(axis=1)
    # Check for multi-class
    if y_pred[0].size > 1:
        print("doing multiclass classification...")
        # We have to reshape our predictions to get them ready for plotting
        y_pred = np.argmax(y_pred, axis=1).reshape(xx.shape)
    else:
        print("doing binary classifcation...")
        y_pred = np.round(y_pred).reshape(xx.shape)
    # Plot decision boundary
    plt.contourf(xx, yy, y_pred, cmap=plt.cm.RdYlBu, alpha=0.7)
    plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.RdYlBu)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())

# %%
plot_decision_boundary(model, X_test, y_test)
# Out:
# doing binary classifcation...
