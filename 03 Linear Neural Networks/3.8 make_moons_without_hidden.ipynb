# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_moons

# %% [markdown]
# ### Data

# %%
features, labels = make_moons(n_samples=5000, random_state=42, noise=0.1)

# %%
features.shape, labels.shape
# Out:
# ((5000, 2), (5000,))

# %%
features[:5]
# Out:
# array([[-0.1196884 ,  1.03684845],
#        [ 0.03370055,  0.2493631 ],
#        [ 0.03864294,  0.33033539],
#        [ 0.22222051,  1.03355193],
#        [ 0.74448612,  0.69288687]])

# %%
labels[:5]
# Out:
# array([0, 1, 1, 0, 0], dtype=int64)

# %%
plt.scatter(features[:,0], features[:,1], c = labels, cmap = plt.cm.RdYlBu_r)

# %% [markdown]
# ### Training

# %%
X_train, X_test, y_train, y_test = train_test_split(features, labels, random_state=42)

# %%
model = keras.Sequential()
model.add(keras.layers.Flatten(input_shape=(X_train.shape[1],))) # I/P
model.add(keras.layers.Dense(2, activation='softmax')) # O/P

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 2)                 0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 6
# =================================================================
# Total params: 6
# Trainable params: 6
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
                optimizer = tf.keras.optimizers.Adam(lr = 0.01),
                metrics = ['accuracy'])

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10)
# Out:
# Epoch 1/10
# 118/118 [==============================] - 0s 3ms/step - loss: 0.3003 - accuracy: 0.8512 - val_loss: 0.2593 - val_accuracy: 0.8776
# Epoch 2/10
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2681 - accuracy: 0.8707 - val_loss: 0.2418 - val_accuracy: 0.8864
# Epoch 3/10
# 118/118 [==============================] - 0s 2ms/step - loss: 0.2584 - accuracy: 0.8768 - val_loss: 0.2368 - val_accuracy: 0.8888
# Epoch 4/10
# 118/118 [==============================] - 0s 2ms/step - loss: 0.2554 - accuracy: 0.8768 - val_loss: 0.2334 - val_accuracy: 0.8896
# Epoch 5/10
# 118/118 [==============================] - 0s 2ms/step - loss: 0.2547 - accuracy: 0.8779 - val_loss: 0.2329 - val_accuracy: 0.8896
# Epoch 6/10
# 118/118 [==============================] - 0s 2ms/step - loss: 0.2545 - accuracy: 0.8776 - val_loss: 0.2324 - val_accuracy: 0.8912
# Epoch 7/10
# 118/118 [==============================] - 0s 2ms/step - loss: 0.2546 - accuracy: 0.8789 - val_loss: 0.2316 - val_accuracy: 0.8896
# Epoch 8/10
# 118/118 [==============================] - 0s 2ms/step - loss: 0.2544 - accuracy: 0.8784 - val_loss: 0.2314 - val_accuracy: 0.8888
# Epoch 9/10
# 118/118 [==============================] - 0s 2ms/step - loss: 0.2545 - accuracy: 0.8768 - val_loss: 0.2316 - val_accuracy: 0.8880
# Epoch 10/10
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2543 - accuracy: 0.8781 - val_loss: 0.2311 - val_accuracy: 0.8888

# %% [markdown]
# ### Plot Decision Boundary

# %%
def plot_decision_boundary(model, X, y):
    # Define the axis boundaries of the plot and create a meshgrid
    x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
    y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100),
                       np.linspace(y_min, y_max, 100))
    # Create X values (we're going to predict on all of these)
    x_in = np.c_[xx.ravel(), yy.ravel()] 
    # Make predictions using the trained model
    y_pred = model.predict(x_in)
    # Check for multi-class
    if len(y_pred[0]) > 1:
        print("doing multiclass classification...")
        # We have to reshape our predictions to get them ready for plotting
        y_pred = np.argmax(y_pred, axis=1).reshape(xx.shape)
    else:
        print("doing binary classifcation...")
        y_pred = np.round(y_pred).reshape(xx.shape)
    # Plot decision boundary
    plt.contourf(xx, yy, y_pred, cmap=plt.cm.RdYlBu, alpha=0.7)
    plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.RdYlBu)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())

# %%
plot_decision_boundary(model, features, labels)
# Out:
# doing multiclass classification...
